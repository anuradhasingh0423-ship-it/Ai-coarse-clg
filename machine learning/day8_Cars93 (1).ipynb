# %%
# take a word from user and check if has 'i' at 2nd place or not ,
  print yes or no.
# take a number from user and check if it is divisible by 7 or not,
  print yes or no
# open cars93 dataset , check null values
# show the distribution of width col
# check for outliers in MPG.highway
# show the relation between price and horsepower
# show the correlation between price,weight,enginesize and id
# take Origin column as output and evaluate the score using random forest
  algorithm

# %%
# take a word from user and check if has 'i' at 2nd place or not ,
# print yes or no.
word = input("Enter a word: ")

if len(word) >= 2 and word[1] == 'i':
    print("Yes")
else:
    print("No")
# Out:
# Enter a word: hiee
# Yes

# %%
# take a number from user and check if it is divisible by 7 or not,
  #print yes or no
num = int(input('Enter a number:'))
if num%7 == 0:
  print('yes')
else:
  print('no')
# Out:
# Enter a number:5
# no

# %%
# open cars93 dataset , check null values
import pandas as pd
df = pd.read_csv('Cars93.csv')

df.isnull().sum()
# Out:
# Id                     0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags               37
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#     Id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi              90  Compact       25.9   29.1       32.3
# 4    5            BMW            535i  Midsize       23.7   30.0       36.2
# 5    6          Buick         Century  Midsize       14.2   15.7       17.3
# 6    7          Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8          Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9          Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac         Seville  Midsize       37.5   40.1       42.7
# 12  13      Chevrolet         Corsica  Compact       11.4   11.4       11.4
# 13  14      Chevrolet          Camaro   Sporty       13.4   15.1       16.8
# ...

# %%
# show the distribution of width col
df.columns
df['Width'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure()
sns.boxplot(y=df["MPG.highway"])
plt.title("Outliers in MPG.highway")
plt.show()

# %%
# check for outliers in MPG.highway
df['MPG.highway'].plot(kind='box')
# Out:
# <Axes: >

# %%
plt.figure()
sns.scatterplot(x=df["Horsepower"], y=df["Price"])
plt.title("Price vs Horsepower")
plt.xlabel("Horsepower")
plt.ylabel("Price")
plt.show()

# %%
# show the relation between price and horsepower
df.plot(kind='scatter', x = 'Price',y = 'Horsepower')
# Out:
# <Axes: xlabel='Price', ylabel='Horsepower'>

# %%
df.columns
# Out:
# Index(['Id', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
# show the correlation between price,weight,enginesize and id
df[['Price','Weight','EngineSize','Id']].corr()
# Out:
#                Price    Weight  EngineSize        Id
# Price       1.000000  0.628830    0.493519 -0.069957
# Weight      0.628830  1.000000    0.898597 -0.360587
# EngineSize  0.493519  0.898597    1.000000 -0.427360
# Id         -0.069957 -0.360587   -0.427360  1.000000

# %%
cols = ["Price", "Weight", "EngineSize", "Id"]

corr = df[cols].corr()
print(corr)

plt.figure()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
# Out:
#                Price    Weight  EngineSize        Id
# Price       1.000000  0.628830    0.493519 -0.069957
# Weight      0.628830  1.000000    0.898597 -0.360587
# EngineSize  0.493519  0.898597    1.000000 -0.427360
# Id         -0.069957 -0.360587   -0.427360  1.000000

# %%
# separating cat and num cols
cat = []
con = []
for i in df.columns:
  if df[i].dtypes == object:
    cat.append(i)
  else:
    con.append(i)

# %%
print(cat)
print(con)
# Out:
# ['Manufacturer', 'Model', 'Type', 'AirBags', 'DriveTrain', 'Cylinders', 'Man.trans.avail', 'Origin', 'Make']
# ['Id', 'Min.Price', 'Price', 'Max.Price', 'MPG.city', 'MPG.highway', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room', 'Weight']

# %%
# creating dataframes from list of cat and con col names

xcat = df[cat]
xcon = df[con]

# %%
xcat
# Out:
#      Manufacturer           Model     Type             AirBags DriveTrain  \
# 1           Acura          Legend  Midsize  Driver & Passenger      Front
# 2            Audi              90  Compact         Driver only      Front
# 4             BMW            535i  Midsize         Driver only       Rear
# 5           Buick         Century  Midsize         Driver only      Front
# 6           Buick         LeSabre    Large         Driver only      Front
# 7           Buick      Roadmaster    Large         Driver only       Rear
# 8           Buick         Riviera  Midsize         Driver only      Front
# 9        Cadillac         DeVille    Large         Driver only      Front
# 10       Cadillac         Seville  Midsize  Driver & Passenger      Front
# 12      Chevrolet         Corsica  Compact         Driver only      Front
# 13      Chevrolet          Camaro   Sporty  Driver & Passenger       Rear
# 17      Chevrolet         Caprice    Large         Driver only       Rear
# ...

# %%
# preprocessing >> feature encoding and feature scaling
from sklearn.preprocessing import LabelEncoder, StandardScaler

le = LabelEncoder()
ss = StandardScaler()

# %%
#feature encoding
for i in xcat.columns:
  xcat[i] = le.fit_transform(xcat[i])
# Out:
# /tmp/ipython-input-1395679985.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xcat[i] = le.fit_transform(xcat[i])
# /tmp/ipython-input-1395679985.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xcat[i] = le.fit_transform(xcat[i])
# /tmp/ipython-input-1395679985.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
xcat
# Out:
#     Manufacturer  Model  Type  AirBags  DriveTrain  Cylinders  \
# 1              0     32     2        0           1          2
# 2              1      6     0        1           1          2
# 4              2      3     2        1           2          0
# 5              3     16     2        1           1          0
# 6              3     30     1        1           1          2
# 7              3     39     1        1           2          2
# 8              3     38     2        1           1          2
# 9              4     23     1        1           1          3
# 10             4     43     2        0           1          3
# 12             5     20     0        1           1          0
# 13             5     11     4        0           2          2
# 17             5     14     1        1           2          3
# 19             6     18     1        0           1          2
# 20             7     29     0        0           1          0
# ...

# %%
# feature scaling
# xcon = ss.fit_transform(xcon)
# -3 to 3 is range of StandardScalar , if the values are not in range then it is considered as outlier
xcon = pd.DataFrame(ss.fit_transform(xcon), columns = con)
xcon
# Out:
#           Id  Min.Price     Price  Max.Price  MPG.city  MPG.highway  \
# 0  -1.551505   1.113167  1.183547   1.185158 -0.789082    -0.886767
# 1  -1.514685   0.736213  0.698883   0.635442 -0.351656    -0.648740
# 2  -1.441044   0.484911  0.789758   0.970425  0.085770     0.303368
# 3  -1.404224  -0.600259 -0.654139  -0.652957  0.085770     0.541394
# 4  -1.367404   0.050843 -0.139183  -0.275027 -0.570369    -0.172686
# 5  -1.330584   0.359260  0.153635  -0.000168 -1.226508    -0.886767
# 6  -1.293763   0.781905  0.416162   0.120082 -0.570369    -0.410713
# 7  -1.256943   1.547235  1.264325   0.979015 -1.226508    -0.886767
# 8  -1.220123   2.061263  1.809572   1.528731 -1.226508    -0.886767
# 9  -1.146482  -0.920099 -1.088317  -1.159727  0.741909     1.255475
# 10 -1.109662  -0.691642 -0.714722  -0.695904 -0.570369    -0.172686
# 11 -0.962381  -0.166191 -0.341126  -0.455403 -1.007795    -0.648740
# 12 -0.888740  -0.120500 -0.381515  -0.558475 -0.351656    -0.172686
# ...

# %%
x = xcon.join(xcat)
x
# Out:
#           Id  Min.Price     Price  Max.Price  MPG.city  MPG.highway  \
# 0  -1.551505   1.113167  1.183547   1.185158 -0.789082    -0.886767
# 1  -1.514685   0.736213  0.698883   0.635442 -0.351656    -0.648740
# 2  -1.441044   0.484911  0.789758   0.970425  0.085770     0.303368
# 3  -1.404224  -0.600259 -0.654139  -0.652957  0.085770     0.541394
# 4  -1.367404   0.050843 -0.139183  -0.275027 -0.570369    -0.172686
# 5  -1.330584   0.359260  0.153635  -0.000168 -1.226508    -0.886767
# 6  -1.293763   0.781905  0.416162   0.120082 -0.570369    -0.410713
# 7  -1.256943   1.547235  1.264325   0.979015 -1.226508    -0.886767
# 8  -1.220123   2.061263  1.809572   1.528731 -1.226508    -0.886767
# 9  -1.146482  -0.920099 -1.088317  -1.159727  0.741909     1.255475
# 10 -1.109662  -0.691642 -0.714722  -0.695904 -0.570369    -0.172686
# 11 -0.962381  -0.166191 -0.341126  -0.455403 -1.007795    -0.648740
# 12 -0.888740  -0.120500 -0.381515  -0.558475 -0.351656    -0.172686
# ...

# %%
# dividing into training and testing
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2)

# %%
# model building
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=5)
model.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(n_estimators=5)

# %%
tr_pred = model.predict(xtrain)
ts_pred = model.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix

tr_con = confusion_matrix(ytrain, tr_pred)
print(tr_con)
# Out:
# [[19  0]
#  [ 0 21]]

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(ytest, ts_pred)
print(mse)
r2 = r2_score(ytest, ts_pred)
print(r2)
import matplotlib.pyplot as plt
plt.scatter(ytest, ts_pred)
plt.show()
# Out:
# 0.09090909090909091
# 0.5416666666666666

# %%
''' create a machine learning model with output as 'Price'
from Cars93 and evaluate the score and error by using RandomForest Regressor with 10 estimators '''
1 import
2 null value treatment
3 divide x and y
4 divide category and num cols
5 create dataframe of cat and con
6 feature encoding >> label encoder
7 feature scaling >> StandardScaler
8 join xcon and xcat
9 train test split
10 model building >> important algo and create model
11 model evaluation
