# %% [markdown]
# ### NLP
# it is a branch of Artificial Intelligence that enables computers to understand, interpret, and generate human language (text or speech).
#
# It sits at the intersection of AI, Machine Learning, and Linguistics, helping machines work with language the way humans do.

# %% [markdown]
# ## 1️⃣ Natural Language Understanding (NLU)
#
#  Helps the computer understand human language.
#
# 🔹 What NLU does:
#
# Understands meaning, context, and intent
#
# Converts text into structured data
#
# 🔹 Key NLU components:
#
# Lexical Analysis – word-level processing
#
# Syntactic Analysis (Parsing) – grammar & sentence structure
#
# Semantic Analysis – meaning of words & sentences
#
# Discourse Integration – meaning across sentences
#
# Pragmatic Analysis – meaning based on real-world context
#
#  Example:
# “Book a flight to Delhi”
# → Intent: Flight booking
# → Entity: Delhi
#
#
# ## 2️⃣ Natural Language Generation (NLG)
#
#  Helps the computer generate human-like language.
#
# 🔹 What NLG does:
#
# Converts data into readable text
#
# Produces responses, summaries, reports
#
# 🔹 Key NLG components:
#
# Content Determination – what to say
#
# Sentence Planning – how to say it
#
# Text Realization – grammar & fluency
#
#  Example:
# Data → “Your flight to Delhi is confirmed.”

# %% [markdown]
# # ML % DL difference
# # Feature extraction technique
#
# >>1. count vectorizer
# it tokenizes text input into the sequence of tokens (N grams)
#
# >>2. TF-IDF  (term frequency- inverse document frequency)
# it is a statistical measure that evaluates how relevant a word is to a document in a collection of documents.

# %% [markdown]
# # steps for preprocessing
#
# 1. convert all text into upper or lower
# 2. removing stopwords
# 3. removing punctuation
# 4. tokenization
#
# Text preprocessing involves converting text to lowercase, removing punctuation and stopwords, and tokenizing text into meaningful units.

# %%
text = 'I am superwomen, dedicated in learning and enjoying a dhamakedaar life. Also want to have all the good food from all the corners of the world(veg food).'

# %%
# split text by whitespace
tokens = text.split()
print(tokens)
# Out:
# ['I', 'am', 'superwomen,', 'dedicated', 'in', 'learning', 'and', 'enjoying', 'a', 'dhamakedaar', 'life.', 'Also', 'want', 'to', 'have', 'all', 'the', 'good', 'food', 'from', 'all', 'the', 'corners', 'of', 'the', 'world(veg', 'food).']

# %%
text.split('.')
# Out:
# ['I am superwomen, dedicated in learning and enjoying a dhamakedaar life',
#  ' Also want to have all the good food from all the corners of the world(veg food)',
#  '']

# %%
text.split('a')
# Out:
# ['I ',
#  'm superwomen, dedic',
#  'ted in le',
#  'rning ',
#  'nd enjoying ',
#  ' dh',
#  'm',
#  'ked',
#  '',
#  'r life. Also w',
#  'nt to h',
#  've ',
#  'll the good food from ',
#  'll the corners of the world(veg food).']

# %% [markdown]
# ## **Tokenization**

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['I', 'am', 'superwomen', ',', 'dedicated', 'in', 'learning', 'and', 'enjoying', 'a', 'dhamakedaar', 'life', '.', 'Also', 'want', 'to', 'have', 'all', 'the', 'good', 'food', 'from', 'all', 'the', 'corners', 'of', 'the', 'world', '(', 'veg', 'food', ')', '.']

# %% [markdown]
# ## **Sentence Tokenization**

# %%
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['I am superwomen, dedicated in learning and enjoying a dhamakedaar life.', 'Also want to have all the good food from all the corners of the world(veg food).']

# %% [markdown]
# ## **Stopwords in NLP**

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
len(stopwords.words('english'))
# Out:
# 198

# %%
print(stopwords.fileids())
# Out:
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']

# %%
text = """He determined to drop his litigation with the monastry, and relinguish his claims to the wood-cuting and
          fishery rihgts at once. He was the more ready to do this becuase the rights had become much less valuable, and he had
          indeed the vaguest idea where the wood and river in question were. """

# %%
# set of stop words
stop_words = set(stopwords.words('english'))

# tokens of words
word_tokens = word_tokenize(text)
filtered_sentence = [] # list of storing words other than stop words

for w in word_tokens:
  if w not in stop_words:
    filtered_sentence.append(w)

# %%
print("\n Original Sentence \n")
print(" ".join(word_tokens))

print("\n Filtered Sentence \n")
print(" ".join(filtered_sentence))
# Out:
#  Original Sentence
#
# He determined to drop his litigation with the monastry , and relinguish his claims to the wood-cuting and fishery rihgts at once . He was the more ready to do this becuase the rights had become much less valuable , and he had indeed the vaguest idea where the wood and river in question were .
#
#  Filtered Sentence
#
# He determined drop litigation monastry , relinguish claims wood-cuting fishery rihgts . He ready becuase rights become much less valuable , indeed vaguest idea wood river question .

# %% [markdown]
# ## **SpaCy**

# %%
import spacy

# !python -m spacy download en_core_web_sm

from collections import Counter
from string import punctuation

# %%
nlp = spacy.load('en_core_web_sm')

# %%
def get_hotwords(text):
  result = []
  pos_tag = ['PROPN', 'ADJ', 'NOUN']
  doc = nlp(text.lower())
  for token in doc:
    if(token.text in nlp.Defaults.stop_words or token.text in punctuation):

      continue
    if(token.pos_ in pos_tag):
      result.append(token.text)
  return result

# %%
new_text = """
           When it comes to evaluating the performance of keyword extractors, you can use some of the standard metrics in machine learning: accuracy, precision, recall, and F1 score. However, these metrics don’t reflect partial matches. they only consider the perfect match between an extracted segment and the correct prediction for that tag.
           Fortunately, there are some other metrics capable of capturing partial matches. An example of this is ROUGE.
           """

# %%
output = set(get_hotwords(new_text))
most_common_list = Counter(output).most_common(10)

for item in most_common_list:
  print(item[0])
# Out:
# accuracy
# score
# f1
# capable
# correct
# precision
# metrics
# recall
# extractors
# perfect

# %% [markdown]
# ## **Porter's Stemmer**

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

print(ps.stem('stemming'))
# Out:
# stem

# %%
sentence =  "It is good to be a pythoner who is pythonly pythoning with python"
words = nltk.word_tokenize(sentence)
for word in words:
  print(ps.stem(word))
# Out:
# it
# is
# good
# to
# be
# a
# python
# who
# is
# pythonli
# python
# with
# python

# %% [markdown]
# ## **Snowball Stemmer**

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('english')
word = 'civilization'
print(stemmer.stem(word))
# Out:
# civil

# %%
sentence = "It is good to be a pythoner who is pythonly pythoning with python"
word = nltk.word_tokenize(sentence)
for word in words:
  stemmer = SnowballStemmer(language = 'english')
  print(stemmer.stem(word))
# Out:
# it
# is
# good
# to
# be
# a
# python
# who
# is
# python
# python
# with
# python

# %% [markdown]
# ## **Lancaster Stemmer**

# %%
from nltk.stem import SnowballStemmer, LancasterStemmer
sentence = "It is good to be a pythoner who is pythonly pythoning with python"
words = nltk.word_tokenize(sentence)
for word in words:
  lanc = LancasterStemmer()
  print(lanc.stem(word))
# Out:
# it
# is
# good
# to
# be
# a
# python
# who
# is
# python
# python
# with
# python

# %%
tokenized_eu = word_tokenize(text)
ps = PorterStemmer()
porter_eu = [ps.stem(word) for word in tokenized_eu]
print(f" PorterStemmer: {100*round(len(''.join(porter_eu))/len(''.join(word_tokenize(text))),3)}%")

snowball = SnowballStemmer(language='english')
porter_eu = [snowball.stem(word) for word in tokenized_eu]
print(f" SnowballStemmer: {100*round(len(''.join(porter_eu))/len(''.join(word_tokenize(text))),3)}%")

lanc = LancasterStemmer()
porter_eu = [lanc.stem(word) for word in tokenized_eu]
print(f" LancasterStemmerr: {100*round(len(''.join(porter_eu))/len(''.join(word_tokenize(text))),3)}%")
# Out:
#  PorterStemmer: 90.3%
#  SnowballStemmer: 92.0%
#  LancasterStemmerr: 87.0%

# %% [markdown]
# ##**Lemmatization**

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
porter = PorterStemmer()
lemmatizer = WordNetLemmatizer()

print(f" better\n Stemming: {porter.stem('better')}\n Lemmatization: {lemmatizer.lemmatize('better', pos='a')}")
# Out:
#  better
#  Stemming: better
#  Lemmatization: good

# %%
sentence = 'There are mistakes'
print(f" Sentence: {sentence}")


word_list = nltk.word_tokenize(sentence)
print(f" word_list: {word_list}")

lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
print(f"Lemmatization: {lemmatized_output}")
# Out:
#  Sentence: There are mistakes
#  word_list: ['There', 'are', 'mistakes']
# Lemmatization: There are mistake

# %% [markdown]
# ## **Lemmatization vs Stemming**
#
# 1.Stemming is faster than lemmatization because it simply chops off prefixes/suffixes using rules.
#
# 2.Lemmatization is slower because it uses a dictionary + POS tagging.

# %% [markdown]
# ## **Bag-of-words**
#
# counts the number of occurence of word in each document(sentence)

# %%
text = ['This is the first document.',
        'This document is the second document.',
        'And this is third one.',
        'Is this the first document.']

print(text)
# Out:
# ['This is the first document.', 'This document is the second document.', 'And this is third one.', 'Is this the first document.']

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(text)
columns = vectorizer.get_feature_names_out()

df = pd.DataFrame(X.toarray(), columns = columns, index = text)
df
# Out:
#                                        and  document  first  is  one  second  \
# This is the first document.              0         1      1   1    0       0
# This document is the second document.    0         2      0   1    0       1
# And this is third one.                   1         0      0   1    1       0
# Is this the first document.              0         1      1   1    0       0
#
#                                        the  third  this
# This is the first document.              1      0     1
# This document is the second document.    1      0     1
# And this is third one.                   0      1     1
# Is this the first document.              1      0     1
